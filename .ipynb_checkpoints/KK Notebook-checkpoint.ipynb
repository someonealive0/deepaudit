# %%
import pandas as pd
import os
from openpyxl import Workbook
import matplotlib.pyplot as plt
from collections import defaultdict
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
files = []
for i in os.walk('./datasets_excel/'):
    files=i[2]

workbooks = {}
for file in files:
    workbooks[file.split('.')[0]] = pd.read_excel('./datasets_excel/' + file, sheet_name=None)

# %%
print(list(workbooks.keys()))
# Out:
# ['ADH_FY', 'ADH_HY', 'ANZ_FY', 'ANZ_HY', 'BCI_FY', 'BCI_HY', 'BFG_FY', 'BFG_HY', 'BHP_FY', 'BHP_HY', 'BNL_FY', 'BNL_HY', 'BPG_FY', 'BPG_HY', 'BTR_FY', 'BTR_HY', 'CBA_FY', 'CBA_HY', 'CCC_FY', 'CCC_HY', 'CIM_FY', 'CIM_HY', 'CVR_FY', 'CVR_HY', 'DGX_FY', 'DGX_HY', 'DTZ_FY', 'DTZ_HY', 'GMN_FY', 'GMN_HY', 'HWK_FY', 'HWK_HY', 'JBH_FY', 'JBH_HY', 'LCT_FY', 'LCT_HY', 'MEB_FY', 'MEB_HY', 'MFG_FY', 'MFG_HY', 'MGC_FY', 'MGC_HY', 'MQG_FY', 'MQG_HY', 'NAB_FY', 'NAB_HY', 'NCM_FY', 'NCM_HY', 'NGI_FY', 'NGI_HY', 'REX_FY', 'REX_HY', 'RIO_FY', 'RIO_HY', 'RNO_FY', 'RNO_HY', 'SRX_FY', 'SRX_HY', 'SRZ_FY', 'SRZ_HY', 'WBC_FY', 'WBC_HY', 'WCC_FY', 'WCC_HY']

# %% [markdown]
# # Beneish M-Score Calculation

# %% [markdown]
# ### 1. To calculate the DSRI
#
# ![image.png](attachment:image.png)

# %%
workbooks['ADH_FY']['Ratio Analysis']
# Out:
#    ASX Code    Company Name                        Item     12/14  \
# 0       ADH  Adairs Limited       Net Profit Margin (%)        --
# 1       ADH  Adairs Limited             EBIT Margin (%)        --
# 2       ADH  Adairs Limited            EBITA Margin (%)        --
# 3       ADH  Adairs Limited           EBITDA Margin (%)        --
# 4       ADH  Adairs Limited                     ROE (%)      0.00
# 5       ADH  Adairs Limited                     ROA (%)      0.00
# 6       ADH  Adairs Limited                    ROIC (%)      0.00
# 7       ADH  Adairs Limited           NOPLAT Margin (%)        --
# 8       ADH  Adairs Limited   Invested Capital Turnover    0.0000
# 9       ADH  Adairs Limited          Inventory Turnover    0.0000
# 10      ADH  Adairs Limited              Asset Turnover    0.0000
# 11      ADH  Adairs Limited           LT Asset Turnover    0.0000
# 12      ADH  Adairs Limited                PPE Turnover    0.0000
# 13      ADH  Adairs Limited       Depreciation/PP&E (%)      0.00
# 14      ADH  Adairs Limited    Depreciation/Revenue (%)        --
# 15      ADH  Adairs Limited     Wkg Capital/Revenue (%)        --
# 16      ADH  Adairs Limited        Working Cap Turnover    0.0000
# 17      ADH  Adairs Limited          Financial Leverage    2.0715
# 18      ADH  Adairs Limited     Gross Gearing (D/E) (%)     64.29
# 19      ADH  Adairs Limited             Net Gearing (%)     82.02
# 20      ADH  Adairs Limited          Net Interest Cover        --
# 21      ADH  Adairs Limited               Current Ratio    0.6893
# 22      ADH  Adairs Limited                 Quick Ratio   -0.1820
# 23      ADH  Adairs Limited               Gross Debt/CF        --
# 24      ADH  Adairs Limited                 Net Debt/CF        --
# 25      ADH  Adairs Limited           NTA per Share ($)   -0.2181
# 26      ADH  Adairs Limited            BV per Share ($)    0.3904
# 27      ADH  Adairs Limited          Cash per Share ($)   -0.0692
# 28      ADH  Adairs Limited    Receivables/Op. Rev. (%)        --
# 29      ADH  Adairs Limited  Inventory/Trading Rev. (%)        --
# 30      ADH  Adairs Limited      Creditors/Op. Rev. (%)        --
# 31      ADH  Adairs Limited  Funds from Ops./EBITDA (%)        --
# 32      ADH  Adairs Limited      Depreciation/Capex (%)        --
# 33      ADH  Adairs Limited    Capex/Operating Rev. (%)        --
# 34      ADH  Adairs Limited              Days Inventory        --
# 35      ADH  Adairs Limited            Days Receivables        --
# 36      ADH  Adairs Limited               Days Payables        --
# 37      ADH  Adairs Limited      Gross CF per Share ($)    0.0000
# 38      ADH  Adairs Limited         Sales per Share ($)    0.0000
# 39      ADH  Adairs Limited        Year End Share Price        --
# 40      ADH  Adairs Limited                 Market Cap.         0
# 41      ADH  Adairs Limited                    Net Debt  53116000
# 42      ADH  Adairs Limited            Enterprise Value  53116000
# 43      ADH  Adairs Limited                   EV/EBITDA        --
# 44      ADH  Adairs Limited                     EV/EBIT        --
# 45      ADH  Adairs Limited        Market Cap./Rep NPAT        --
# 46      ADH  Adairs Limited    Market Cap./Trading Rev.        --
# 47      ADH  Adairs Limited            Price/Book Value    0.0000
# 48      ADH  Adairs Limited       Price/Gross Cash Flow        --
# 49      ADH  Adairs Limited                         PER        --
#
#           06/15        06/16        06/17        06/18        06/19  \
# 0          1.40        10.73         7.93         9.71         8.61
# 1          8.74        16.09        11.63        14.38        12.61
# 2          9.09        16.34        11.90        14.73        12.99
# 3         10.92        18.17        13.85        16.55        14.85
# 4          7.55        28.43        20.95        26.30        25.05
# 5         16.43        16.68        11.61        16.21        14.51
# 6         50.68        44.70        39.76        55.88        56.06
# 7          6.33        11.51         8.70        10.38         9.22
# 8          8.01         3.88         4.57         5.38         6.08
# 9         18.14         9.64         8.03         9.38         8.05
# 10         2.68         1.48         1.38         1.61         1.64
# 11         3.54         2.05         1.88         2.24         2.43
# 12        38.54        15.82        13.12        15.07        16.51
# 13        18.58         9.07         9.22         9.16        10.02
# 14         1.83         1.84         1.95         1.82         1.86
# 15        -4.73         1.65         2.04         2.40         1.56
# 16       -84.61        60.64        48.94        41.70        63.98
# 17         2.02         1.79         1.92         1.68         1.78
# 18        53.47        43.73        41.78        21.48        21.09
# 19        41.36        28.38        27.51        10.53         6.97
# 20         1.33        21.17        16.29        31.32        37.45
# 21         1.14         1.66         1.62         1.59         1.48
# 22         0.45         0.74         0.59         0.61         0.56
# 23         4.77         1.24         1.53         0.65         0.65
# 24         3.69         0.80         1.01         0.32         0.22
# 25        -0.14        -0.03        -0.09         0.01         0.03
# 26         0.47         0.58         0.60         0.70         0.71
# 27         0.06         0.09         0.09         0.08         0.10
# 28         0.92         0.22         0.00         0.00         0.00
# 29        22.04        10.38        12.45        10.66        12.42
# 30        22.49         6.08         9.96         8.61         8.61
# 31       162.68        90.41       121.21        99.60        95.43
# 32        56.09        45.03        45.58        80.61        91.88
# 33         3.26         4.08         4.28         2.25         2.02
# 34        20.12        37.88        45.45        38.92        45.34
# 35         0.84         0.81         0.00         0.00         0.00
# 36        20.53        22.19        36.36        31.44        31.43
# 37         0.23         0.20         0.17         0.23         0.23
# 38         2.78         1.53         1.60         1.88         2.08
# 39         2.66         2.47         0.86         2.23         1.42
# 40 441227500.00 409711250.00 142652500.00 369901250.00 235542500.00
# 41  32242000.00  27124000.00  27598000.00  12237000.00   8241000.00
# 42 473469500.00 436835250.00 170250500.00 382138250.00 243783500.00
# 43        41.13         9.49         4.64         7.34         4.77
# 44        51.36        10.72         5.53         8.44         5.61
# 45      1184.50        15.08         6.79        12.10         7.95
# 46         4.18         1.62         0.54         1.18         0.68
# 47         5.66         4.29         1.42         3.18         1.99
# 48        50.45        12.13         5.20         9.60         6.18
# 49       274.23        15.08         6.79        12.19         7.95
#
#           06/20        06/21
# 0         10.07        13.49
# 1         16.16        21.28
# 2         16.34        21.56
# 3         26.26        30.20
# 4         27.86        40.93
# 5         11.19        17.50
# 6         32.09        58.14
# 7         11.36        14.80
# 8          2.82         3.93
# 9          8.96         7.35
# 10         1.00         1.20
# 11         1.25         1.62
# 12         3.38         4.51
# 13        23.66        26.20
# 14         9.93         8.65
# 15        -1.11        -9.18
# 16       -89.74       -10.89
# 17         2.77         2.52
# 18        99.26        65.10
# 19        82.24        49.33
# 20        10.20        14.32
# 21         0.82         0.67
# 22         0.36         0.24
# 23         1.67         0.90
# 24         1.39         0.68
# 25        -0.33        -0.19
# 26         0.83         0.97
# 27         0.14         0.15
# 28         0.00         0.00
# 29        11.16        13.61
# 30         8.04         8.77
# 31       104.97        93.23
# 32       512.63       380.80
# 33         1.94         2.27
# 34        40.73        49.66
# 35         0.00         0.00
# 36        29.33        32.00
# 37         0.49         0.68
# 38         2.28         2.86
# 39         2.30         4.25
# 40 388877272.00 718577568.00
# 41 115605000.00  81224000.00
# 42 504482272.00 799801568.00
# 43         4.94         5.30
# 44         8.03         7.52
# 45        11.02        11.27
# 46         1.00         1.44
# 47         2.77         4.36
# 48         4.67         6.04
# 49        10.01        11.01

# %%
workbooks['ADH_FY']['Ratio Analysis']['Days Receivables']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\keert\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\users\keert\appdata\local\programs\python\python38-32\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\users\keert\appdata\local\programs\python\python38-32\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Days Receivables'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-80dfcfb5221a> in <module>
# ----> 1 workbooks['ADH_FY']['Ratio Analysis']['Days Receivables']
#
# c:\users\keert\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\users\keert\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Days Receivables'

# %%
def DSRI(workbooks.keys['ADH_FY']['Ratio Analysis'])

# %% [markdown]
# Data found in Ratio Analysis Sheet

# %% [markdown]
# ### 2. To calculate the GMI
#
#
# $ \large{\text{Gross Margin Index (GMI) }}= \LARGE{\frac{\text{Gross margin}_{t-1}}{\text{Gross margin}_t}} $

# %% [markdown]
# Use Net Profit Margin instead

# %% [markdown]
# ### 3. To calculate the AQI
#
#
#
# $\large{\text{Asset Quality Index (AQI) }} = \huge{\frac{1 - \frac{\text{Property plant and equipment}_t + \text{ Current assets}_t}{\text{Total assets}_t}}{1-\frac{\text{Property plant and equipment}_{t-1} + \text{ Current assets}_{t-1}}{\text{Total assets}_{t-1}}}} $

# %% [markdown]
# (Total Assets - (Total Current Assets + NCA PP&E))/Total Assets)

# %% [markdown]
# ### 4. To calculate the SGI
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5. To calculate the DEPI
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 6. To calculate the SGAI
#
# $\large{\text{Sales General and Administrative Expenses Index (SGAI) }}= \huge{\frac{\frac{\text{Sales, general, and administrative expenses}_t}{Sales_t}}{\frac{\text{Sales, general, and administrative expenses}_{t-1}}{Sales_{t-1}}}} $

# %% [markdown]
# ### 7. To calculate the LVGI
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 8. To calculate the TATA
#
# $\large{\text{Total Accruals to Total Assets (TATA) }} = \LARGE{\frac{\text{Inc. before extr. items} - \text{ Cash from operations}}{\text{Total assets}}} $

# %% [markdown]
# ### 9. M-Score Calculation
#
#
#
#
# $\large{\text{M-Score }}= \large{–4.84 + 0.920 (DSRI) + 0.528 (GMI) + 0.404 (AQI) + 0.892 (SGI) + 0.115 (DEPI) -0.172 (SGAI) + 4.679 (TATA) – 0.327 (LVGI)}$
#
#
# The companies whose m-score are higher than -1.78 are considered likely to have manipulated their earnings, while those under -2.22 are considered that have fairer reports.
